# %%
def func(*args):
    return sum(args) * 0.05
sumv = func(10,10)
print(sumv)
# Out:
# 1.0

# %%
def func(**kwargs):
    return kwargs['fruit']
sumv = func(fruit=10,vegetable=100)
print(sumv)
# Out:
# 10

# %%
def func(*args,**kwargs):
        return("i would like {} {}".format(args[0],kwargs['fruit']))
sumv = func(10,20,fruit='orange')
print(sumv)
# Out:
# i would like 10 orange

# %%
 def func(*args):
    evenList = []
    print(evenList)
    for i in args:
        print(i)
        if(i%2==0):
            print("even")
            evenList.append(i)
    print(evenList)
func(10,10,31)
# Out:
# []
# 10
# even
# 10
# even
# 31
# [10, 10]
