# %%
class Circle():
    '''
    This is the code for Circle
    Function includes : 
        radius
        area
        Circumferance
    '''
    ## class object attribute
    pi = 3.14
    ## constructor  ## with argument 
    def __init__(self,radi=1):
        self.radi = radi
        # area is an type of attribute which is self defined 
        self.area = self.pi*self.radi*self.radi
    ## methods 1 with argument 
    def circumference(self,radi):
        circum = 2*self.pi*self.radi
        return(circum)
    
    ## method 2 without arguments 
    def diameter(self):
        return(2*self.radi)

# %%
myChoice = "2" #Circle
## type casting 
## create a dictionary 1=Circle,2=square,3=rectange
## create three different classess
## call either of them on the choice of user.
## u have take further choice of whether he wishes to have the area /diameter ?
if(int(myChoice) == 1):
    myCircle = Circle(8)
    mySquare = Square(8)
    myRect = Rectangle(10)
    
    print(myCircle.area)
else:
    print("condition mismatch")
    print(myCircle1.area)
# Out:
# condition mismatch
# 200.96
