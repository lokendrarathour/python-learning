# %%
echo 1
# Out:
# 1

# %%
import os
files = []
for i in os.listdir("G:\Ganaaa"):
    print(i)
    if i.endswith('.e'):
        src = i
        dest = (src.split('.')[0])+".mp3"
        print(dest)
        print(i)
        print(src)
        os.rename(i, dest)
# Out:
# 37069 (115).e
# 37069 (115).mp3
# 37069 (115).e
# 37069 (115).e
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-565217d5c356> in <module>()
#       9         print(i)
#      10         print(src)
# ---> 11         os.rename(i, dest)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: '37069 (115).e' -> '37069 (115).mp3'
