# %%
print("hello")
# Out:
# hello

# %%
print("hello")
print("hello")
print("hello")
print("hello")
# Out:
# hello
# hello
# hello
# hello

# %%
#variable asigntion- variable are empty placeholder 
a=5
print(a)
type(a)
b=2
c=a/b
print(c)
d=a%b #will print the reminder
print(d)
# Out:
# 5
# 2.5
# 1

# %%
e=50%10
print(e)
f=40/10
print(F)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7fdb92a96b5c> in <module>()
#       2 print(e)
#       3 f=40/10
# ----> 4 print(F)
#
# NameError: name 'F' is not defined

# %%
a=(3+4)*(44/4)
print(a)
type(a)
# Out:
# 77.0
# float

# %%
#recmondation - variable shld in lower-case
INDER=44
#dynamically typing language 
inder="singh"
type(inder)
#inder=44
#type(inder)
# Out:
# str

# %%
a="tr"
b="res"
c=a+b
print(c)


_a="abc"
print(_a)
# Out:
# trres
# abc

# %%
abt="inder\"s is learning python"
print(abt)
#escape sequence
# Out:
# inder"s is learning python

# %%
#\n \t
abt="inders \n is \t learning python"
#tab       
print(abt)
# Out:
# inders
#  is 	 learning python

# %%
#\n \t
abt="inders is learning python"
print(len(abt))
# print the last character
print(abt[5])
# string_name[postion] postion starts from 
# Slicing
print(abt[4:])
print(abt[4:11])
print(abt[10])

# steps
print(abt)
ab="easdhgtklbvnxm"
print(ab[::2])
# Out:
# 25
# s
# rs is learning python
# rs is l
# l
# inders is learning python
# eshtlvx

# %%
ab="easdhgtklbvnxm"
print(ab[::2])
print(ab[1:5:3])

print(ab[::-1])
# Out:
# eshtlvx
# ah
# mxnvblktghdsae

# %%
a='twinke'[1:4]
print(a)
# Out:
# win

# %%
a="Inder "
b="is learning"
cdd=a+b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-a555b8e09a94> in <module>()
#       2 b="is learning"
#       3 cdd=a+b
# ----> 4 print(sort(cdd))
#
# NameError: name 'sort' is not defined

# %%
#take a string and do the following
#print string taken
#	print only the second element of the string
#	print every alternate character of the string
#	reverse the string and print the alternate character
	
#Consider a string "Hello this is loke"s world"
#	print the length of last word in the string
#	print the string as it is.

# %%
name="Inder"
print(name)
# variable as
a=name[1]
print(a)
# Out:
# Inder
# n
