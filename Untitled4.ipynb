# %%
def fun(a,b,c):
    print("Number recieved is "+str(a))
fun(10,30,20)
# Out:
# Number recieved is 10

# %%
def fun(a,b,c):
    if(a > b): 
        print("a is greater than b so print "+str(b))
    if(b > c):
        print("b is greater than c so print "+str(c))
a = input("Please ener first value")
print(a)
fun(40,30,20)

# %%
def fun(a,b=0,c=0):
    if(a[0] > a[1]): 
        print("a is greater than b so print "+str(b))
    else:
        print("a>b condition failed")
    if(b > c):
        print("b is greater than c so print "+str(c))
    else:
        print("failed condition check")
        
myList = []
a = input("Please ener first value a ")
b = input("Please ener first value b ")
c = input("Please ener first value c ")
myList.append(a)
myList.append(b)
myList.append(c)
print(myList)
#print(a)
#fun(a,b,c)
fun(myList)
# Out:
# Please ener first value a 10
# Please ener first value b 20
# Please ener first value c 30
# ['10', '20', '30']
# a>b condition failed
# failed condition check

# %%
def fun(*args):
    print(args)
    EvenList = []
    for i in args:
        if(i%2 == 0):
            EvenList.append(i)
            #print("we are at even place {}".format(i))
            ##return("we are at even place {}".format(i))
    return(EvenList)
#a = input("Please ener first value a ")
#b = input("Please ener first value b ")
#c = input("Please ener first value c ")
#d = input("Please ener first value d ")

#print(myList)
#print(a)
evencheck = fun(50,1,2,3,4)
#fun(50,1,2,3,4)

print(evencheck)
# Out:
# (50, 1, 2, 3, 4)
# [50, 2, 4]

# %%
def fun(*args,**kwargs):
    print(args)
    print(kwargs)

evencheck = fun(10,fans=6,20,30,40,chairs=4,bed=2)

print(evencheck)
# Out:
#   File "<ipython-input-27-a05df216f5ae>", line 5
#     evencheck = fun(10,fans=6,20,30,40,chairs=4,bed=2)
#                              ^
# SyntaxError: positional argument follows keyword argument

# %%
def reverseStr(arg):
    words = arg.split(' ')
    reverseString = words[::-1]
    return(reverseString)

def strexa(arg):
    print(len(arg))
    if(len(arg) > 100):
        first_part = arg[:3].capitalize()
        second_part = arg[3:].capitalize()
        NewString = first_part+second_part
    else:
        reverseString = reverseStr(arg)
        print("The String entered is " + arg)
        print(reverseString)
   ## print("The processed string is "+ NewString)
strexa("Macdownalds is a food outlet")
# Out:
# 28
# The String entered is Macdownalds is a food outlet
# ['outlet', 'food', 'a', 'is', 'Macdownalds']
