# %%
pwd
# Out:
# 'C:\\Users\\loke'

# %%
# fully qualified
myf = open("gablearning.txt")
type(myf)
# every new line will replaced with \n
print(myf.read())
# Out:
# hello
# hello
# hello
# hello
# hello this is the second line
# hello this is the fourh line
# gab
# hello
# there
# etc
# etc
# insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");
# insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');
# insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');
# insert into table sessionschedule (schedule) values ('Mo')
# select * from sessionschedule sc,sessionoccurance so where
# insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");
# insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');
# insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');
# insert into table sessionschedule (schedule) values ('Mo')
# select * from sessionschedule sc,sessionoccurance so where

# %%
#print(myf.read())
#myf.seek(0)
#print(myf.read())
myf.seek(10)
print(myf.read())
# Out:
# lo
# hello
# hello
# hello this is the second line
# hello this is the fourh line
# gab
# hello
# there
# etc
# etc
# insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");
# insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');
# insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');
# insert into table sessionschedule (schedule) values ('Mo')
# select * from sessionschedule sc,sessionoccurance so where
# insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");
# insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');
# insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');
# insert into table sessionschedule (schedule) values ('Mo')
# select * from sessionschedule sc,sessionoccurance so where

# %%
myf.seek(0)
content = myf.read()
print(content)
print(content)
# Out:
# hello
# hello
# hello
# hello
# hello this is the second line
# hello this is the fourh line
# gab
# hello
# there
# etc
# etc
# insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");
# insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');
# insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');
# insert into table sessionschedule (schedule) values ('Mo')
# select * from sessionschedule sc,sessionoccurance so where
# insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");
# insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');
# insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');
# insert into table sessionschedule (schedule) values ('Mo')
# select * from sessionschedule sc,sessionoccurance so where
# hello
# hello
# hello
# hello
# hello this is the second line
# hello this is the fourh line
# gab
# hello
# there
# etc
# ...

# %%
myf.seek(0)
#content = myf.readline()
content = myf.readlines()
print(content)
#print(type(content))
# Out:
# ['hello\n', 'hello\n', 'hello\n', 'hello\n', 'hello this is the second line\n', 'hello this is the fourh line\n', 'gab\n', 'hello\n', 'there \n', 'etc\n', 'etc\n', 'insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");\n', "insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');\n", "insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');\n", "insert into table sessionschedule (schedule) values ('Mo')\n", 'select * from sessionschedule sc,sessionoccurance so where\n', 'insert into  sessionschedule (schedule,description) values ("Daily","Mon-Sun");\n', "insert into  sessionschedule (schedule,description) values ('Weekly','Mon-Fri');\n", "insert into  sessionschedule (schedule,description) values ('Weekends','Sat-Sun');\n", "insert into table sessionschedule (schedule) values ('Mo')\n", 'select * from sessionschedule sc,sessionoccurance so where']

# %%
pwd
# Out:
# 'C:\\Users\\loke'

# %%
myf = open("C:\\Users\\loke\gablearing.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-b138e69c6be1> in <module>()
# ----> 1 myf = open("C:\\Users\\loke\gablearing.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\loke\\gablearing.txt'

# %%
# closing the file 
myf.close()
