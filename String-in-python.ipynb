# %%
name="Inder"
print(name)
# variable as
a=name[1]
# variable a is holding n
print(a)

# %%
name="Inder"
myname=name
print(myname)
# immutable nautre of the string elements
#name[1]='is'
a=4
a="issss"
a=name[1]
name[1]='d'
# Out:
# Inder
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-cebdef1fcc2f> in <module>()
#       7 a="issss"
#       8 a=name[1]
# ----> 9 name[1]='d'
#
# TypeError: 'str' object does not support item assignment

# %%
letter='s'

letter*100
#
'2'*'3'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-1a81c9fecd68> in <module>()
#       3 letter*100
#       4 #
# ----> 5 '2'*'3'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
mystg="This is pthon learning"
cnt=mystg.lower()
mystg.capitalize()
print(cnt)
mystg.split("i")
mystg.join()
# Out:
# this is pthon learning
# ['Th', 's ', 's pthon learn', 'ng']

# %%
# Assigment : 
# explore all the function available in string 
#stake a string of your choice and split on the basis of desired character

# %%
# print 
# formating of string in python


sname="Inder"
lname="singh"

print("Hello "+sname)

print("my name is {}".format("InderSingh"))
#FORMAT
#

print("my name is {0} {1} {0}".format(sname,lname,'learning'))

print("my name is " + sname+ lname+"learning")
# Out:
# Hello Inder
# my name is InderSingh
# my name is Inder singh Inder
# my name is Indersinghlearning

# %%
cal=100/3
print("the result is {r}".format(r=cal))
print("the result is {r:10.4f}".format(r=cal))

print("the result is {r:1.4f}".format(r=cal))
# Out:
# the result is 33.333333333333336
# the result is    33.3333
# the result is 33.3333

# %%
#### lists in Python
## ordered seq which holds different or same type of datatypes. 
## it can be a collection of integer, integer or float inter or any combination

inder=[1,2,3,4,5,6]
type(inder)
# Out:
# list

# %%
myl=['inder',4,5.03,4,"singh"]
print(myl)
myl[0:]
myl[1:]
myl[::-1]
# Out:
# ['inder', 4, 5.03, 4, 'singh']
# ['singh', 4, 5.03, 4, 'inder']

# %%
myl1=['33','re',5.03,4,"singh"]
print(myl1)
myl3=myl+myl1
print(myl3)
myl4=myl1+myl
print(myl4)
print(myl4[2:])
# Out:
# ['33', 're', 5.03, 4, 'singh']
# ['inder', 4, 5.03, 4, 'singh', '33', 're', 5.03, 4, 'singh']
# ['33', 're', 5.03, 4, 'singh', 'inder', 4, 5.03, 4, 'singh']
# [5.03, 4, 'singh', 'inder', 4, 5.03, 4, 'singh']

# %%
# Assignment 2
# create a integer list of 10 elements and sum the second and last index value of the list.
