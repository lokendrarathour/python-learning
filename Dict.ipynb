# %% [markdown]
# myD =
# {'x':'10','apple':'2','grapes':1,'banana':2,'orange':3,'Indian_apple':'3'}
# print(myD)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a186247e26a> in <module>()
# ----> 1 print(myD)
#
# NameError: name 'myD' is not defined
