# %%
'Gab is learning'
# Out:
# 'Gab is learning'

# %%
"Gab is learning"
# Out:
# 'Gab is learning'

# %%
var ="I'm going to \n run"
print(var)
# Out:
# I'm going to
#  run

# %%
var = "Ga is learning"
print(var)
print(len(var))
print(var[0])
print(var[-14])
# Out:
# Ga is learning
# 14
# G
# G

# %%
## string slicing 
var = "Ga is learning"
print(var[4])
# Out:
# s

# %%
##Slicing:   [Start:stop:steps]
var = "Ga is learning"
print(var[0:4:1])
print(var[0:10:2])  ## 
print(var[4:])
print(var[1:4])
print(var[::2])
# Out:
# Ga i
# G sla
# s learning
# a i
# G slann

# %%
var = "Ga is learning"
var1 = (var[0:4:1])
var2 = var[0:10:2]  ## 
## var 2 is itself a string and this can be used at any other point of time

var3 = (var[4:])
var4 = (var[1:4])

print(var4)
# Out:
# a i

# %%
str1 = "I live in"
str2 = " India"
str3 = str1 + str2

str3 = str3 + " OK"

# %%
letter="G"
letter*100
# Out:
# 'GGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG'

# %%
'2'+'3'
# Out:
# '23'

# %%
letter = "India"
letter.upper()
letter.lower()
# Out:
# 'india'

# %%
var = "I live in country India"
var1= var.split()
print(var1)
len(var1)
print(var1[2])
# Out:
# ['I', 'live', 'in', 'country', 'India']
# in
