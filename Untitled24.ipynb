# %%
winner=input("Please enter the winner of 2011 world cup")
# Out:
# Please enter the winner of 2011 world cupIndia is india and india is india

# %%
print(winner)
w=winner.split()
print(winner)
print(w)
# Out:
# India is india and india is india
# India is india and india is india
# ['India', 'is', 'india', 'and', 'india', 'is', 'india']
