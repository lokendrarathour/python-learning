# %%
myS="this is the first program i am creating in Jypy"

# %%
print(myS)
# Out:
# this is the first program i am creating in Jypy

# %%
myL = [1,2,2,3,4,5]

# %%
print(myL)
# Out:
# [1, 2, 2, 3, 4, 5]

# %%
print(myS[-1])
# Out:
# y

# %%
print(myL[-1])
# Out:
# 5

# %%
myL.append(6)
print(myL)
# Out:
# [1, 2, 2, 3, 4, 5, 6]

# %%
myT=(1,2,3,4,1,2)
print(myT)
# Out:
# (1, 2, 3, 4, 1, 2)

# %%
type(myT)
# Out:
# tuple

# %%
myT.count(1)
# Out:
# 2

# %%
print(myT[0])
# Out:
# 1

# %%
b = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-54ec162aed60> in <module>()
# ----> 1 b = none
#
# NameError: name 'none' is not defined

# %%
myD = {'x':'10','apple':'2','grapes':1,'banana':2,'orange':3,'apple':'3'}
print(myD)
# Out:
# {'x': '10', 'apple': '3', 'grapes': 1, 'banana': 2, 'orange': 3}

# %%
myD['strawberry'] = 3
print(myD)
# Out:
# {'x': '10', 'apple': '3', 'grapes': 1, 'banana': 2, 'orange': 3, 'strawberry': 3}

# %%
myD['x']= 12
print(myD)
# Out:
# {'x': 12, 'apple': '3', 'grapes': 1, 'banana': 2, 'orange': 3, 'strawberry': 3}

# %%
myD['mango'] = [1,5,4,3,6]
print(myD)
# Out:
# {'x': 12, 'apple': '3', 'grapes': 1, 'banana': 2, 'orange': 3, 'strawberry': 3, 'mango': [1, 5, 4, 3, 6]}

# %%
print(myD['mango'])
# Out:
# [1, 3, 4, 5, 6]

# %%
prices = myD['mango'][1]
print(prices)
# Out:
# 3

# %%
print(myD.keys())
# Out:
# dict_keys(['x', 'apple', 'grapes', 'banana', 'orange', 'strawberry', 'mango'])

# %%
print(myD.values())
# Out:
# dict_values([12, '3', 1, 2, 3, 3, [1, 3, 4, 5, 6]])

# %%
print(myD.items())
# Out:
# dict_items([('x', 12), ('apple', '3'), ('grapes', 1), ('banana', 2), ('orange', 3), ('strawberry', 3), ('mango', [1, 3, 4, 5, 6])])

# %%
print(myD)
# Out:
# {'x': 12, 'apple': '3', 'grapes': 1, 'banana': 2, 'orange': 3, 'strawberry': 3, 'mango': [1, 3, 4, 5, 6]}

# %%
mySet = set()
mySet.add(2)
print(mySet)
mySet.add(2)
print(mySet)
mySet.add(3)
print(mySet)
mySet.add(4)
print(mySet)
# Out:
# {2}
# {2}
# {2, 3}
# {2, 3, 4}

# %%
type(True)
# Out:
# bool

# %%
print(1>2)
# Out:
# False

# %%
print(200<10)
# Out:
# False

# %%
myvar = 1
print(myvar == 1)
# Out:
# True
