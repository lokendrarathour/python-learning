# %%
add = 2000+34567
print(add)
## it is just a variable do not get confused 
add = 4599
print(add)
# Out:
# 36567
# 4599

# %%
3/2
# Out:
# 1.5

# %%
int(3/2)  #typecasting
# Out:
# 1

# %%
##mod operator  (%)
7/4
# Out:
# 1.75

# %%
7%4  ##4*1+3
# Out:
# 3

# %%
50%5  ## 5*10+0
# Out:
# 0

# %%
23%2  ## 2*11+1
# Out:
# 1

# %%
2 ** 3  ## 2 power 3
# Out:
# 8

# %%
## BODMAS -- bracet or Div Mul Add subtra
2 + 100 * 100 + 3
# Out:
# 10005

# %%
(2+100) * (100 + 3)
# Out:
# 10506

# %%
(2+100) ** 2
# Out:
# 10404

# %%
type((2+100) ** 2)
# Out:
# int

# %%
## integer
var = 2
print(type(var))
## list
var = ["student1","student2"]
print(type(var))
## python allows dynamic typing assignation
## in other languages it will be a problem
# Out:
# <class 'int'>
# <class 'list'>

# %%
a= 45
b= 60
c= a+b/100
print(c)
type(c)
# Out:
# 45.6
# float

# %%
my_i = 100
my_t = 0.04
tax = my_i * my_t
print(int(tax))
# Out:
# 4
